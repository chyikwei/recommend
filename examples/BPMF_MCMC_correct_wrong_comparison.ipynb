# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# In the following figure you can see a comparison of the train and test RMSE computed during training for the wrong MCMC sampling algorithm and the correct one. A you can notice, the correct one gives better results.

# %%
D=70
results_part=results.loc[results['Number of features']==D]
results_part_corr=results_correct.loc[results['Number of features']==D]
plt.figure(figsize=(8,4.5))
plt.xlabel('Number of iterations')
plt.ylabel('RMSE')

plt.plot(np.arange(len(results_part['Train RMSE'])), results_part['Test RMSE'], label='Test RMSE wrong')
plt.plot(np.arange(len(results_part_corr['Train RMSE'])), results_part_corr['Test RMSE'], label='Test RMSE correct')
plt.plot(np.arange(len(results_part['Train RMSE'])), results_part['Train RMSE'], label='Training RMSE wrong')
plt.plot(np.arange(len(results_part_corr['Train RMSE'])), results_part_corr['Train RMSE'], label='Training RMSE correct')
plt.legend()
plt.show()
